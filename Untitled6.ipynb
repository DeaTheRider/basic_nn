# %%
from __future__ import print_function

from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
from keras.layers import GRU
from keras.optimizers import Adam

from keras.datasets import imdb


import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from sklearn.metrics import mean_squared_error

numpy.random.seed(7)

max_features = 2000

# обрезание текстов после данного количества слов (среди top max_features наиболее используемые слова)
maxlen = 80
batch_size = 6 * 128 # увеличьте значение для ускорения обучения

print('Загрузка данных...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'тренировочные последовательности')
print(len(x_test), 'тестовые последовательности')

print('Pad последовательности (примеров в x единицу времени)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)

print('Построение модели...')
model = Sequential()
model.add(Embedding(max_features, 512))
model.add(LSTM(512, dropout=0.5, recurrent_dropout=0.5,return_sequences=False))
model.add(Dense(1, activation='relu'))

# стоит попробовать использовать другие оптимайзер и другие конфигурации оптимайзеров 
adam = Adam(learning_rate=0.005,  amsgrad=True)
model.compile(loss='binary_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])



print('Процесс обучения...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=10, # увеличьте при необходимости
          validation_data=(x_test, y_test))
score, acc = model.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Результат при тестировании:', score)
print('Тестовая точность:', acc)
# Out:
# Using TensorFlow backend.
# Загрузка данных...
# 25000 тренировочные последовательности
# 25000 тестовые последовательности
# Pad последовательности (примеров в x единицу времени)
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)
# Построение модели...
# Процесс обучения...
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
# 25000/25000 [==============================] - 14s 568us/step - loss: 1.1389 - accuracy: 0.5766 - val_loss: 0.6774 - val_accuracy: 0.6707
# Epoch 2/10
# 25000/25000 [==============================] - 14s 544us/step - loss: 0.7804 - accuracy: 0.6977 - val_loss: 1.0783 - val_accuracy: 0.7271
# Epoch 3/10
# 25000/25000 [==============================] - 14s 549us/step - loss: 1.4975 - accuracy: 0.6878 - val_loss: 1.3562 - val_accuracy: 0.7102
# Epoch 4/10
# 25000/25000 [==============================] - 14s 553us/step - loss: 0.8066 - accuracy: 0.6385 - val_loss: 0.6519 - val_accuracy: 0.5938
# Epoch 5/10
# 25000/25000 [==============================] - 14s 543us/step - loss: 0.5918 - accuracy: 0.6977 - val_loss: 0.5863 - val_accuracy: 0.7283
# Epoch 6/10
# 25000/25000 [==============================] - 14s 541us/step - loss: 0.5810 - accuracy: 0.7424 - val_loss: 0.6299 - val_accuracy: 0.6227
# Epoch 7/10
# 25000/25000 [==============================] - 13s 539us/step - loss: 0.5545 - accuracy: 0.7380 - val_loss: 0.5390 - val_accuracy: 0.7451
# Epoch 8/10
# 25000/25000 [==============================] - 14s 543us/step - loss: 0.4885 - accuracy: 0.7924 - val_loss: 0.5299 - val_accuracy: 0.7794
# Epoch 9/10
# 25000/25000 [==============================] - 14s 547us/step - loss: 0.4432 - accuracy: 0.8187 - val_loss: 0.4644 - val_accuracy: 0.7964
# Epoch 10/10
# 25000/25000 [==============================] - 14s 545us/step - loss: 0.4210 - accuracy: 0.8303 - val_loss: 0.5361 - val_accuracy: 0.8104
# 25000/25000 [==============================] - 3s 132us/step
# Результат при тестировании: 0.5361441705703736
# Тестовая точность: 0.8103600144386292

# %%
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)

print('Построение модели...')
model2 = Sequential()
model2.add(Embedding(max_features, 512))
model2.add(GRU(512, dropout=0.5,return_sequences=True))
model2.add(GRU(512, dropout=0.5,return_sequences=False))
model2.add(Dense(1, activation='sigmoid'))

# стоит попробовать использовать другие оптимайзер и другие конфигурации оптимайзеров 
model2.compile(loss='binary_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])

print('Процесс обучения...')
model2.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=25, # увеличьте при необходимости
          validation_data=(x_test, y_test))
score2, acc2 = model2.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Результат при тестировании:', score2)
print('Тестовая точность:', acc2)
# Out:
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)
# Построение модели...
# Процесс обучения...
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/25
# 25000/25000 [==============================] - 25s 989us/step - loss: 0.8761 - accuracy: 0.5035 - val_loss: 0.7189 - val_accuracy: 0.5014
# Epoch 2/25
# 25000/25000 [==============================] - 24s 951us/step - loss: 0.7058 - accuracy: 0.5093 - val_loss: 0.6986 - val_accuracy: 0.5114
# Epoch 3/25
# 25000/25000 [==============================] - 24s 950us/step - loss: 0.6978 - accuracy: 0.5139 - val_loss: 0.6946 - val_accuracy: 0.5181
# Epoch 4/25
# 25000/25000 [==============================] - 24s 958us/step - loss: 0.6981 - accuracy: 0.5128 - val_loss: 0.6967 - val_accuracy: 0.5139
# Epoch 5/25
# 25000/25000 [==============================] - 24s 951us/step - loss: 0.6958 - accuracy: 0.5193 - val_loss: 0.6967 - val_accuracy: 0.5162
# Epoch 6/25
# 25000/25000 [==============================] - 24s 943us/step - loss: 0.6946 - accuracy: 0.5234 - val_loss: 0.6913 - val_accuracy: 0.5292
# Epoch 7/25
# 25000/25000 [==============================] - 24s 944us/step - loss: 0.6914 - accuracy: 0.5308 - val_loss: 0.7045 - val_accuracy: 0.5101
# Epoch 8/25
# 25000/25000 [==============================] - 24s 949us/step - loss: 0.6882 - accuracy: 0.5420 - val_loss: 0.6938 - val_accuracy: 0.5196
# Epoch 9/25
# 25000/25000 [==============================] - 24s 950us/step - loss: 0.6847 - accuracy: 0.5458 - val_loss: 0.6886 - val_accuracy: 0.5467
# Epoch 10/25
# 25000/25000 [==============================] - 24s 972us/step - loss: 0.6833 - accuracy: 0.5458 - val_loss: 0.6896 - val_accuracy: 0.5519
# Epoch 11/25
# 25000/25000 [==============================] - 24s 945us/step - loss: 0.6778 - accuracy: 0.5634 - val_loss: 0.6754 - val_accuracy: 0.5660
# Epoch 12/25
# 25000/25000 [==============================] - 24s 950us/step - loss: 0.6752 - accuracy: 0.5654 - val_loss: 0.6758 - val_accuracy: 0.5763
# Epoch 13/25
# 25000/25000 [==============================] - 24s 949us/step - loss: 0.6667 - accuracy: 0.5823 - val_loss: 0.6731 - val_accuracy: 0.5802
# Epoch 14/25
# 25000/25000 [==============================] - 24s 950us/step - loss: 0.6636 - accuracy: 0.5854 - val_loss: 0.6723 - val_accuracy: 0.5864
# Epoch 15/25
# 25000/25000 [==============================] - 24s 951us/step - loss: 0.6623 - accuracy: 0.5891 - val_loss: 0.6894 - val_accuracy: 0.5447
# Epoch 16/25
# 25000/25000 [==============================] - 24s 966us/step - loss: 0.6622 - accuracy: 0.5903 - val_loss: 0.6613 - val_accuracy: 0.5986
# Epoch 17/25
# 25000/25000 [==============================] - 24s 948us/step - loss: 0.6560 - accuracy: 0.6012 - val_loss: 0.6618 - val_accuracy: 0.6009
# Epoch 18/25
# 25000/25000 [==============================] - 24s 956us/step - loss: 0.6524 - accuracy: 0.6078 - val_loss: 0.6592 - val_accuracy: 0.6056
# Epoch 19/25
# 25000/25000 [==============================] - 24s 950us/step - loss: 0.6479 - accuracy: 0.6101 - val_loss: 0.6576 - val_accuracy: 0.6062
# Epoch 20/25
# 25000/25000 [==============================] - 24s 947us/step - loss: 0.6521 - accuracy: 0.6075 - val_loss: 0.6717 - val_accuracy: 0.5716
# Epoch 21/25
# 25000/25000 [==============================] - 24s 949us/step - loss: 0.6481 - accuracy: 0.6118 - val_loss: 0.6536 - val_accuracy: 0.6109
# Epoch 22/25
# 25000/25000 [==============================] - 24s 963us/step - loss: 0.6448 - accuracy: 0.6160 - val_loss: 0.6501 - val_accuracy: 0.6117
# Epoch 23/25
# 25000/25000 [==============================] - 24s 957us/step - loss: 0.6386 - accuracy: 0.6256 - val_loss: 0.6504 - val_accuracy: 0.6124
# Epoch 24/25
# 25000/25000 [==============================] - 24s 960us/step - loss: 0.6410 - accuracy: 0.6238 - val_loss: 0.6515 - val_accuracy: 0.6076
# Epoch 25/25
# 25000/25000 [==============================] - 24s 948us/step - loss: 0.6392 - accuracy: 0.6206 - val_loss: 0.6506 - val_accuracy: 0.6093
# 25000/25000 [==============================] - 6s 222us/step
# Результат при тестировании: 0.6506421762466431
# Тестовая точность: 0.609279990196228

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd gdrive/My\ Drive
# Out:
# /content/gdrive/My Drive

# %%
import numpy as np
from keras.layers import Dense, Activation
from keras.layers.recurrent import SimpleRNN, LSTM, GRU
from keras.models import Sequential


# построчное чтение из примера с текстом 
with open("ЕвгенийОнегин.txt", 'rb') as _in:
    lines = []
    for line in _in:
        line = line.strip().lower().decode("utf-8", "ignore")
        if len(line) == 0:
            continue
        lines.append(line)
text = " ".join(lines)
chars = set([c for c in text])
nb_chars = len(chars)


# создание индекса символов и reverse mapping чтобы передвигаться между значениями numerical
# ID and a specific character. The numerical ID will correspond to a column
# ID и определенный символ. Numerical ID будет соответсвовать колонке
# число при использовании one-hot кодировки для представление входов символов
char2index = {c: i for i, c in enumerate(chars)}
index2char = {i: c for i, c in enumerate(chars)}

# для удобства выберете фиксированную длину последовательность 10 символов 
SEQLEN, STEP = 50, 1
input_chars, label_chars = [], []

# конвертация data в серии разных SEQLEN-length субпоследовательностей
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i: i + SEQLEN])
    label_chars.append(text[i + SEQLEN])


# Вычисление one-hot encoding входных последовательностей X и следующего символа (the label) y

X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1


# установка ряда метапамертров  для нейронной сети и процесса тренировки
BATCH_SIZE, HIDDEN_SIZE = 512, 256
NUM_ITERATIONS = 25 # 25 должно быть достаточно
NUM_EPOCHS_PER_ITERATION = 10
NUM_PREDS_PER_EPOCH = 100


# Create a super simple recurrent neural network. There is one recurrent
# layer that produces an embedding of size HIDDEN_SIZE from the one-hot
# encoded input layer. This is followed by a Dense fully-connected layer
# across the set of possible next characters, which is converted to a
# probability score via a standard softmax activation with a multi-class
# cross-entropy loss function linking the prediction to the one-hot
# encoding character label.

'''
Создание очень простой рекуррентной нейронной сети. В ней будет один реккурентный закодированный входной слой. За ним последует полносвязный слой связанный с набором возможных следующих символов, которые конвертированы в вероятностные результаты через стандартную softmax активацию с multi-class cross-encoding loss функцию ссылающуются на предсказание one-hot encoding лейбл символа
'''

model = Sequential()
model.add(
    GRU(  # вы можете изменить эту часть на LSTM или SimpleRNN, чтобы попробовать альтернативы
        HIDDEN_SIZE,
        return_sequences=False,
        input_shape=(SEQLEN, nb_chars),
        unroll=True
    )
)
model.add(Dense(nb_chars))
model.add(Activation("softmax"))
model.compile(loss="categorical_crossentropy", optimizer="adam")


# выполнение серий тренировочных и демонстрационных итераций 
for iteration in range(NUM_ITERATIONS):

    # для каждой итерации запуск передачи данных в модель 
    print("=" * 50)
    print("Итерация #: %d" % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)

    # Select a random example input sequence.
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]

    # для числа шагов предсказаний использование текущей тренируемой модели 
    # конструирование one-hot encoding для тестирования input и добавление предсказания.
    print("Генерация из посева: %s" % (test_chars))
    print(test_chars, end="")
    for i in range(NUM_PREDS_PER_EPOCH):

        # здесь one-hot encoding.
        X_test = np.zeros((1, SEQLEN, nb_chars))
        for j, ch in enumerate(test_chars):
            X_test[0, j, char2index[ch]] = 1

        # осуществление предсказания с помощью текущей модели.
        pred = model.predict(X_test, verbose=0)[0]
        y_pred = index2char[np.argmax(pred)]

        # вывод предсказания добавленного к тестовому примеру 
        print(y_pred, end="")

        # инкрементация тестового примера содержащего предсказание
        test_chars = test_chars[1:] + y_pred
print()
# Out:
# ==================================================
# Итерация #: 0
# Epoch 1/10
# 139592/139592 [==============================] - 14s 97us/step - loss: 3.0505
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 2.5293
# Epoch 3/10
# 139592/139592 [==============================] - 11s 80us/step - loss: 2.4073
# Epoch 4/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 2.3206
# Epoch 5/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 2.2497
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 2.1858
# Epoch 7/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 2.1288
# Epoch 8/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 2.0769
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 2.0282
# Epoch 10/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.9798
# Генерация из посева:  суждено. Полюбите вы снова: но... Учитесь властво
#  суждено. Полюбите вы снова: но... Учитесь властвой не свете Привет постеленный полой И в солец в образной не свет. Но в не вольно полно не свете Под ==================================================
# Итерация #: 1
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.9342
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.8902
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.8451
# Epoch 4/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.8041
# Epoch 5/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 1.7614
# Epoch 6/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 1.7191
# Epoch 7/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.6794
# Epoch 8/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.6396
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.5983
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 1.5577
# Генерация из посева: т Эола; То стан совьет, то разовьет, И быстрой нож
# т Эола; То стан совьет, то разовьет, И быстрой ножки простованный, И полной поле отворат, И в старенным семеной страх, И полной поле отворал, И всё пр==================================================
# Итерация #: 2
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.5180
# Epoch 2/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 1.4785
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.4371
# Epoch 4/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.3984
# Epoch 5/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 1.3594
# Epoch 6/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.3227
# Epoch 7/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 1.2841
# Epoch 8/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 1.2498
# Epoch 9/10
# 139592/139592 [==============================] - 11s 80us/step - loss: 1.2150
# Epoch 10/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 1.1817
# Генерация из посева: нил Всегда возвышенные чувства, Порывы девственной
# нил Всегда возвышенные чувства, Порывы девственной лене, Какой-нибудь, и последней... Но вы часто перед нею Смертал И дама старина. Свой повад, и душа==================================================
# Итерация #: 3
# Epoch 1/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 1.1522
# Epoch 2/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 1.1215
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.0935
# Epoch 4/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 1.0666
# Epoch 5/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 1.0401
# Epoch 6/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 1.0173
# Epoch 7/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.9940
# Epoch 8/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.9720
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.9518
# Epoch 10/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.9268
# Генерация из посева: им сейчас была Так равнодушна, так смела? Он остав
# им сейчас была Так равнодушна, так смела? Он оставляет им гостей Подобло наслажданый Веселье Тани приводит и Расседа снега руко Евгений любовь И все б==================================================
# Итерация #: 4
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.9089
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.8923
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.8739
# Epoch 4/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.8579
# Epoch 5/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.8401
# Epoch 6/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.8273
# Epoch 7/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.8110
# Epoch 8/10
# 139592/139592 [==============================] - 11s 80us/step - loss: 0.7975
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.7854
# Epoch 10/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.7726
# Генерация из посева: печальной Таней наш приятель; Не в первый раз он т
# печальной Таней наш приятель; Не в первый раз он тот мора-но Тать не посленное стала. И вставь — Онянье на була внемь ходу бежал И с нем печто прикажд==================================================
# Итерация #: 5
# Epoch 1/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.7614
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.7467
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.7335
# Epoch 4/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.7240
# Epoch 5/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.7156
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.7046
# Epoch 7/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.6919
# Epoch 8/10
# 139592/139592 [==============================] - 11s 80us/step - loss: 0.6831
# Epoch 9/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.6765
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.6676
# Генерация из посева: савиц модных модный враг, Где этот пасмурный чудак
# савиц модных модный враг, Где этот пасмурный чудак. Но рамом моим моя скучья, И на прольбивою леск, Как верчив, он не сосед На собе протитси кладкий с==================================================
# Итерация #: 6
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.6616
# Epoch 2/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.6509
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.6413
# Epoch 4/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.6319
# Epoch 5/10
# 139592/139592 [==============================] - 11s 80us/step - loss: 0.6279
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.6181
# Epoch 7/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.6174
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.6051
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5993
# Epoch 10/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5953
# Генерация из посева: ше бедное жилище, За те места, где в первый раз, О
# ше бедное жилище, За те места, где в первый раз, Онегин, всегда не могу... И вашей голост опуть их родной Над этом с себе, устарела, На столесь и вида==================================================
# Итерация #: 7
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5898
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5798
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5739
# Epoch 4/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.5686
# Epoch 5/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.5634
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.5590
# Epoch 7/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.5521
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.5500
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5423
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.5374
# Генерация из посева: а голове седой, Старушку в длинной телогрейке И вс
# а голове седой, Старушку в длинной телогрейке И все предрежалися читать. Да честь его была оты? Мог двуе молча был роске Нездуюблисься их модной, Дово==================================================
# Итерация #: 8
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5328
# Epoch 2/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.5310
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5247
# Epoch 4/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5236
# Epoch 5/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5175
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.5111
# Epoch 7/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5075
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.5036
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.5001
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.5010
# Генерация из посева: ет на нее, И все кричат: мое! мое! Мое! — сказал Е
# ет на нее, И все кричат: мое! мое! Мое! — сказал Евгений грозно, И мой и спорий своих. В тосте рассернко земетом; Мелькал совершебного письмы Огодь по==================================================
# Итерация #: 9
# Epoch 1/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4984
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4883
# Epoch 3/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4771
# Epoch 4/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.4845
# Epoch 5/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4818
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4748
# Epoch 7/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.4700
# Epoch 8/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.4663
# Epoch 9/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4674
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4668
# Генерация из посева:  мой изнемогает, И молча гибнуть я должна. Я жду т
#  мой изнемогает, И молча гибнуть я должна. Я жду темясь, подругали мне. Устрая, зины, Гилова Иль старался сне гда я. Мечтам и все обмит и душа Себя на==================================================
# Итерация #: 10
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4669
# Epoch 2/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4568
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4546
# Epoch 4/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4438
# Epoch 5/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.4423
# Epoch 6/10
# 139592/139592 [==============================] - 11s 80us/step - loss: 0.4538
# Epoch 7/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.4493
# Epoch 8/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4451
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4427
# Epoch 10/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4303
# Генерация из посева: енили в нем, Согретой девственным огнем. Чуть отро
# енили в нем, Согретой девственным огнем. Чуть отром, лись, долго враги Приятной рукою лужей Блестятельный устрых Она Боть, жардый обид, как. Но уходи ==================================================
# Итерация #: 11
# Epoch 1/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4277
# Epoch 2/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4306
# Epoch 3/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.4280
# Epoch 4/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.4243
# Epoch 5/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4295
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4222
# Epoch 7/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4084
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4148
# Epoch 9/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.4192
# Epoch 10/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4197
# Генерация из посева:  Татьяна пишет. И всё Евгений на уме, И в необдума
#  Татьяна пишет. И всё Евгений на уме, И в необдуманном письме Любовь невинной зелене... Но все хорочить, силит — в каки? Что ж вам? — Не правда ль? Кт==================================================
# Итерация #: 12
# Epoch 1/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.4124
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4165
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4080
# Epoch 4/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.3996
# Epoch 5/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3960
# Epoch 6/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4120
# Epoch 7/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.4016
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3937
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3927
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3963
# Генерация из посева: ный взор, - Онегину всё было ново; Он охладительно
# ный взор, - Онегину всё было ново; Он охладительное строюю; Онегин жило торжен очей Был чержен и веселых след, И слышье Татьяны про дорженьям, С тек п==================================================
# Итерация #: 13
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3942
# Epoch 2/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3936
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3885
# Epoch 4/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3850
# Epoch 5/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3884
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3868
# Epoch 7/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3836
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3781
# Epoch 9/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3802
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3861
# Генерация из посева: вовсе охладел. Как child-harold, угрюмый, томный В
# вовсе охладел. Как child-harold, угрюмый, томный В гостиных появлялся он; Ни спится колобку вамменьем, Кудать, и спорофа шлюства, Потывал ее старанный==================================================
# Итерация #: 14
# Epoch 1/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3643
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3697
# Epoch 3/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.3731
# Epoch 4/10
# 139592/139592 [==============================] - 11s 80us/step - loss: 0.3722
# Epoch 5/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3733
# Epoch 6/10
# 139592/139592 [==============================] - 11s 80us/step - loss: 0.3704
# Epoch 7/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3700
# Epoch 8/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3655
# Epoch 9/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.3601
# Epoch 10/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.3592
# Генерация из посева: все решили так, Что он опаснейший чудак. Сначала в
# все решили так, Что он опаснейший чудак. Сначала все жени нет, никать, Она в ней нирю ими страсти, И сымала по суете смешет В беседовется к вечных тек==================================================
# Итерация #: 15
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3583
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3598
# Epoch 3/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3632
# Epoch 4/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3627
# Epoch 5/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3591
# Epoch 6/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3463
# Epoch 7/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3526
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3546
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3576
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3569
# Генерация из посева: енно углублен. То были тайные преданья Сердечной,
# енно углублен. То были тайные преданья Сердечной, темной старины, Ни с исего спиты и сонд, И прамма я на чисался, Как исповил со всем ступеяе, Живует,==================================================
# Итерация #: 16
# Epoch 1/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3475
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3432
# Epoch 3/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3482
# Epoch 4/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3469
# Epoch 5/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3434
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3389
# Epoch 7/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3356
# Epoch 8/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.3466
# Epoch 9/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3471
# Epoch 10/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3360
# Генерация из посева: зы; Он пел поблеклый жизни цвет Без малого в осьмн
# зы; Он пел поблеклый жизни цвет Без малого в осьмнениет И жинной и лице привожит Младое образмий ей Обредли бедный боян, но любем; И модно жарнительны==================================================
# Итерация #: 17
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3420
# Epoch 2/10
# 139592/139592 [==============================] - 11s 79us/step - loss: 0.3459
# Epoch 3/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3276
# Epoch 4/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3290
# Epoch 5/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3377
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3358
# Epoch 7/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3345
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3356
# Epoch 9/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3250
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3231
# Генерация из посева: едный цвет и вид унылый; И в сладостный, безгрешны
# едный цвет и вид унылый; И в сладостный, безгрешный сон Девимы Мазденки томный был, Привлюдяться дево моей Принял невинный Приеману Гласомешал пенив к==================================================
# Итерация #: 18
# Epoch 1/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3268
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3346
# Epoch 3/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3308
# Epoch 4/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3257
# Epoch 5/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3260
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3205
# Epoch 7/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3301
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3212
# Epoch 9/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3216
# Epoch 10/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3187
# Генерация из посева:  «Увидеть барский дом нельзя ли?» - Спросила Таня.
#  «Увидеть барский дом нельзя ли?» - Спросила Таня. Последная. Я начинает день Его не изменил; он? Что мы нам же вас, боиснет. Внама маличась, малые; Е==================================================
# Итерация #: 19
# Epoch 1/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3189
# Epoch 2/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3135
# Epoch 3/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3200
# Epoch 4/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3400
# Epoch 5/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3083
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3012
# Epoch 7/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3140
# Epoch 8/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3234
# Epoch 9/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3042
# Epoch 10/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3003
# Генерация из посева: авны... Я вышла замуж. Вы должны, Я вас прошу, мен
# авны... Я вышла замуж. Вы должны, Я вас прошу, меня обезоко; Повой коворяю мой! Бесчадных, близба столеской Струсти, судьбу ее побавать? Казать одража==================================================
# Итерация #: 20
# Epoch 1/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3127
# Epoch 2/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3195
# Epoch 3/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3143
# Epoch 4/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3089
# Epoch 5/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3070
# Epoch 6/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3199
# Epoch 7/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3126
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3073
# Epoch 9/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.2924
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3039
# Генерация из посева: Отходит и людей зовет. Зарецкий бережно кладет На
# Отходит и людей зовет. Зарецкий бережно кладет На сани труп олжденьях Наотраду полухосу взор, Вот ваш исты, кот ручой Доступник жизни броримах. На вот==================================================
# Итерация #: 21
# Epoch 1/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3055
# Epoch 2/10
# 139592/139592 [==============================] - 11s 78us/step - loss: 0.3031
# Epoch 3/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.2965
# Epoch 4/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3067
# Epoch 5/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3018
# Epoch 6/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.2967
# Epoch 7/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3025
# Epoch 8/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3033
# Epoch 9/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.2882
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.2877
# Генерация из посева: ней, Но неприступною богиней Роскошной, царственно
# ней, Но неприступною богиней Роскошной, царственной думной, В слугах забев ее поскала С ней оничься потомуке, Поэзи; но все онирать И доже гудеит гене==================================================
# Итерация #: 22
# Epoch 1/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.3066
# Epoch 2/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.3067
# Epoch 3/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.2903
# Epoch 4/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2996
# Epoch 5/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2895
# Epoch 6/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2903
# Epoch 7/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.2882
# Epoch 8/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2901
# Epoch 9/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3137
# Epoch 10/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.3006
# Генерация из посева: озок почтенный, Скользя, ползет за ворота. "Прости
# озок почтенный, Скользя, ползет за ворота. "Простите, мирные мог beef-stakк Ее робещенные лицо; Он песла по насполесь... Куда! сердечно теперь я хото?==================================================
# Итерация #: 23
# Epoch 1/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2898
# Epoch 2/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2761
# Epoch 3/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2746
# Epoch 4/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2786
# Epoch 5/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.3006
# Epoch 6/10
# 139592/139592 [==============================] - 11s 75us/step - loss: 0.3008
# Epoch 7/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2808
# Epoch 8/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2856
# Epoch 9/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2787
# Epoch 10/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2772
# Генерация из посева:  И всех соседей развлекло. Пошла догадка за догадк
#  И всех соседей развлекло. Пошла догадка за догадкой. Сюда такона, на сумах девам, За то же полных учениц. Он был совершевнопать была. То вылою глубок==================================================
# Итерация #: 24
# Epoch 1/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2891
# Epoch 2/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2875
# Epoch 3/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.2819
# Epoch 4/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2860
# Epoch 5/10
# 139592/139592 [==============================] - 11s 77us/step - loss: 0.2835
# Epoch 6/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2787
# Epoch 7/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2750
# Epoch 8/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2695
# Epoch 9/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2857
# Epoch 10/10
# 139592/139592 [==============================] - 11s 76us/step - loss: 0.2832
# Генерация из посева: казал Владимир. И пошли За мельницу. Пока вдали За
# казал Владимир. И пошли За мельницу. Пока вдали Зарецкий на типенья для ноЕжже все ум, Любовью лиром ханниго. Дна согда любим своей станинья. Но давно
